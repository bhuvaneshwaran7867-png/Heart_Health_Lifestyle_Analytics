# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime as dt
import os

# %%
care=pd.read_excel(r"C:\Users\user\Pictures\Desktop\Heart_Health_Lifestyle_Analytics\Dataset\Heart_Health_Lifestyle_Analytics_2000_Records.xlsx")

# %%
care.head()
# Out:
#   Patient_ID  Age  Gender        City  Occupation   BMI  \
# 0     P00001   27  Female  Coimbatore    Business  26.0
# 1     P00002   38  Female      Mumbai    Engineer  18.5
# 2     P00003   23    Male       Delhi      Driver  34.1
# 3     P00004   51  Female   Bengaluru    Business  32.6
# 4     P00005   46    Male      Mumbai  Healthcare  29.0
#
#    Blood_Pressure_Systolic  Cholesterol  Blood_Sugar Smoking  ... Daily_Steps  \
# 0                      173          280          195      No  ...        4712
# 1                      147          233          188      No  ...       15440
# 2                      115          300          186      No  ...       11580
# 3                      163          251          212     Yes  ...       15867
# 4                      110          296          120     Yes  ...       13206
#
#    Sleep_Hours Stress_Level  Fast_Food_Meals_Per_Week  Water_Intake_Liters  \
# 0          6.2            8                        10                  2.1
# 1          6.5           10                         7                  2.4
# 2          6.7            9                         7                  3.8
# 3          7.4            9                         4                  2.6
# 4          4.8            6                        10                  3.0
#
#    Screen_Time_Hours  Family_History  Resting_Heart_Rate  Heart_Attack  \
# 0                5.4              No                  77            No
# 1                6.8              No                  91            No
# 2                5.4             Yes                  73           Yes
# 3               11.6              No                 101            No
# 4                9.5              No                  99            No
#
#   Hospital_Visits_Last_Year
# 0                         6
# 1                         7
# 2                         4
# 3                         7
# 4                         2
#
# [5 rows x 23 columns]

# %%
care.describe()
# Out:
#                Age          BMI  Blood_Pressure_Systolic  Cholesterol  \
# count  2020.000000  1968.000000              2020.000000  2020.000000
# mean     45.616337    27.561585               139.438119   230.907921
# std      15.725381     5.477301                23.015825    51.783845
# min      15.000000    18.000000               100.000000   140.000000
# 25%      33.000000    22.800000               119.000000   187.000000
# 50%      46.000000    27.600000               140.000000   232.000000
# 75%      58.000000    32.400000               159.000000   275.000000
# max     120.000000    37.000000               180.000000   320.000000
#
#        Blood_Sugar  Exercise_Hours_Per_Week   Daily_Steps  Sleep_Hours  \
# count  2020.000000              2020.000000   2020.000000  1949.000000
# mean    150.511881                 4.972525   9803.512871     6.483479
# std      45.718623                 2.911578   4805.175223     1.450198
# min      70.000000                 0.000000   1507.000000     4.000000
# 25%     111.000000                 2.400000   5544.500000     5.200000
# 50%     150.000000                 4.900000   9732.000000     6.500000
# 75%     190.000000                 7.500000  14009.500000     7.700000
# max     230.000000                10.000000  17999.000000     9.000000
#
#        Stress_Level  Fast_Food_Meals_Per_Week  Water_Intake_Liters  \
# count   2020.000000               2020.000000          2020.000000
# mean       5.495545                  5.036634             2.767970
# std        2.807949                  3.161909             0.999915
# min        1.000000                  0.000000             1.000000
# 25%        3.000000                  2.000000             1.900000
# 50%        5.000000                  5.000000             2.800000
# 75%        8.000000                  8.000000             3.700000
# max       10.000000                 10.000000             4.500000
#
#        Screen_Time_Hours  Resting_Heart_Rate  Hospital_Visits_Last_Year
# count        2020.000000         2020.000000                2020.000000
# mean            6.264752           80.039604                   4.974752
# std             3.204446           14.927509                   3.147812
# min             1.000000           55.000000                   0.000000
# 25%             3.500000           67.000000                   2.000000
# 50%             6.100000           80.000000                   5.000000
# 75%             9.000000           93.000000                   8.000000
# max            12.000000          105.000000                  10.000000

# %%
care.sample(10)
# Out:
#      Patient_ID  Age  Gender        City Occupation   BMI  \
# 1683     P01684   64    Male        Pune   Business  24.8
# 1936     P01937   23    Male   Hyderabad   Business  29.9
# 306      P00307   50    Male        Pune         IT  27.3
# 1451     P01452   63    Male     Madurai     Driver  21.8
# 161      P00162   50    Male      Mumbai    Teacher  26.3
# 1031     P01032   33  Female      Mumbai   Engineer  24.0
# 926      P00927   20    Male   Bengaluru    Teacher  33.4
# 1248     P01249   46  Female   Bengaluru    Student  31.3
# 1821     P01822   54  Female   Hyderabad         IT  20.3
# 685      P00686   46  Female  Coimbatore   Engineer  36.2
#
#       Blood_Pressure_Systolic  Cholesterol  Blood_Sugar Smoking  ...  \
# 1683                      172          263           92     Yes  ...
# 1936                      154          185          143      No  ...
# 306                       135          177          108     Yes  ...
# 1451                      110          284          154      No  ...
# 161                       153          259          165     Yes  ...
# 1031                      141          173          227     Yes  ...
# 926                       143          160          116     Yes  ...
# 1248                      121          164          225     Yes  ...
# 1821                      152          188          114      No  ...
# 685                       159          172          150     Yes  ...
#
#      Daily_Steps  Sleep_Hours Stress_Level  Fast_Food_Meals_Per_Week  \
# 1683       14514          8.1            5                         0
# 1936       14470          6.6            4                         7
# 306         3654          6.7            3                         9
# 1451        8518          4.8            1                         5
# 161        15373          4.5            7                         4
# 1031       11602          6.2            7                         2
# 926        15787          5.0            8                         3
# 1248       13361          8.4            2                         2
# 1821        3875          4.8            8                         7
# 685         1517          6.1            7                         2
#
#       Water_Intake_Liters  Screen_Time_Hours  Family_History  \
# 1683                  3.1               10.5              No
# 1936                  2.2                3.4              No
# 306                   4.3                4.2             Yes
# 1451                  4.0                9.5              No
# 161                   3.6                2.0              No
# 1031                  3.0                9.5             Yes
# 926                   2.1                8.4              No
# 1248                  4.2                5.3             Yes
# 1821                  2.6               11.8              No
# 685                   2.1                4.7              No
#
#       Resting_Heart_Rate  Heart_Attack Hospital_Visits_Last_Year
# 1683                  83            No                         4
# 1936                 105            No                         3
# 306                   84            No                         9
# 1451                  90            No                        10
# 161                   85            No                         7
# 1031                  91            No                         5
# 926                   55            No                         9
# 1248                  82           Yes                         1
# 1821                  60           Yes                         5
# 685                  102            No                         6
#
# [10 rows x 23 columns]

# %%
care.tail()
# Out:
#      Patient_ID  Age  Gender        City  Occupation   BMI  \
# 2015     P00016   70    Male     Madurai    Engineer  24.8
# 2016     P00017   40  Female  Coimbatore       Sales  23.0
# 2017     P00018   55  Female        Pune  Healthcare  25.7
# 2018     P00019   54  Female   Bengaluru     Teacher  23.1
# 2019     P00020   64  Female     Madurai       Sales  33.8
#
#       Blood_Pressure_Systolic  Cholesterol  Blood_Sugar Smoking  ...  \
# 2015                      149          188           72      No  ...
# 2016                      138          305          100      No  ...
# 2017                      122          190          188     Yes  ...
# 2018                      173          257          172      No  ...
# 2019                      160          263          156     Yes  ...
#
#      Daily_Steps  Sleep_Hours Stress_Level  Fast_Food_Meals_Per_Week  \
# 2015        2467          4.9            9                         2
# 2016       13253          7.4            8                         9
# 2017       14925          8.2           10                         6
# 2018       12537          4.5            8                        10
# 2019       12202          NaN            4                         7
#
#       Water_Intake_Liters  Screen_Time_Hours  Family_History  \
# 2015                  1.6               10.8             Yes
# 2016                  2.2                1.8             Yes
# 2017                  1.7                5.9             Yes
# 2018                  4.0               11.5             Yes
# 2019                  2.8                7.9              No
#
#       Resting_Heart_Rate  Heart_Attack Hospital_Visits_Last_Year
# 2015                  78           Yes                         1
# 2016                  86            No                         4
# 2017                  82           Yes                         4
# 2018                  82           Yes                         5
# 2019                  60           Yes                         8
#
# [5 rows x 23 columns]

# %%
care.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 2020 entries, 0 to 2019
# Data columns (total 23 columns):
#  #   Column                     Non-Null Count  Dtype
# ---  ------                     --------------  -----
#  0   Patient_ID                 2020 non-null   str
#  1   Age                        2020 non-null   int64
#  2   Gender                     2020 non-null   str
#  3   City                       1982 non-null   str
#  4   Occupation                 2020 non-null   str
#  5   BMI                        1968 non-null   float64
#  6   Blood_Pressure_Systolic    2020 non-null   int64
#  7   Cholesterol                2020 non-null   int64
#  8   Blood_Sugar                2020 non-null   int64
#  9   Smoking                    2020 non-null   str
#  10  Alcohol_Consumption        2020 non-null   str
#  11  Exercise_Hours_Per_Week    2020 non-null   float64
#  12  Gym_Member                 2020 non-null   str
#  13  Daily_Steps                2020 non-null   int64
#  14  Sleep_Hours                1949 non-null   float64
#  15  Stress_Level               2020 non-null   int64
#  16  Fast_Food_Meals_Per_Week   2020 non-null   int64
#  17  Water_Intake_Liters        2020 non-null   float64
#  18  Screen_Time_Hours          2020 non-null   float64
#  19  Family_History             2020 non-null   str
#  20  Resting_Heart_Rate         2020 non-null   int64
#  21  Heart_Attack               2020 non-null   str
#  22  Hospital_Visits_Last_Year  2020 non-null   int64
# dtypes: float64(5), int64(9), str(9)
# memory usage: 449.0 KB

# %%
type(care)
# Out:
# pandas.DataFrame

# %%
care.shape
# Out:
# (2020, 23)

# %%
care.columns
# Out:
# Index(['Patient_ID', 'Age', 'Gender', 'City', 'Occupation', 'BMI',
#        'Blood_Pressure_Systolic', 'Cholesterol', 'Blood_Sugar', 'Smoking',
#        'Alcohol_Consumption', 'Exercise_Hours_Per_Week', 'Gym_Member',
#        'Daily_Steps', 'Sleep_Hours', 'Stress_Level',
#        'Fast_Food_Meals_Per_Week', 'Water_Intake_Liters', 'Screen_Time_Hours',
#        'Family_History', 'Resting_Heart_Rate', 'Heart_Attack',
#        'Hospital_Visits_Last_Year'],
#       dtype='str')

# %%
care.isnull().sum()
# Out:
# Patient_ID                    0
# Age                           0
# Gender                        0
# City                         38
# Occupation                    0
# BMI                          52
# Blood_Pressure_Systolic       0
# Cholesterol                   0
# Blood_Sugar                   0
# Smoking                       0
# Alcohol_Consumption           0
# Exercise_Hours_Per_Week       0
# Gym_Member                    0
# Daily_Steps                   0
# Sleep_Hours                  71
# Stress_Level                  0
# Fast_Food_Meals_Per_Week      0
# Water_Intake_Liters           0
# Screen_Time_Hours             0
# Family_History                0
# Resting_Heart_Rate            0
# Heart_Attack                  0
# Hospital_Visits_Last_Year     0
# dtype: int64

# %%
care.isnull().any()
# Out:
# Patient_ID                   False
# Age                          False
# Gender                       False
# City                          True
# Occupation                   False
# BMI                           True
# Blood_Pressure_Systolic      False
# Cholesterol                  False
# Blood_Sugar                  False
# Smoking                      False
# Alcohol_Consumption          False
# Exercise_Hours_Per_Week      False
# Gym_Member                   False
# Daily_Steps                  False
# Sleep_Hours                   True
# Stress_Level                 False
# Fast_Food_Meals_Per_Week     False
# Water_Intake_Liters          False
# Screen_Time_Hours            False
# Family_History               False
# Resting_Heart_Rate           False
# Heart_Attack                 False
# Hospital_Visits_Last_Year    False
# dtype: bool

# %%
care["City"]=care["City"].fillna("Unrecorded",inplace=True)
# Out:
# C:\Users\user\AppData\Local\Temp\ipykernel_16312\4155000119.py:1: ChainedAssignmentError: A value is being set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# Such inplace method never works to update the original DataFrame or Series, because the intermediate object on which we are setting values always behaves as a copy (due to Copy-on-Write).
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' instead, to perform the operation inplace on the original object, or try to avoid an inplace operation using 'df[col] = df[col].method(value)'.
#
# See the documentation for a more detailed explanation: https://pandas.pydata.org/pandas-docs/stable/user_guide/copy_on_write.html
#   care["City"]=care["City"].fillna("Unrecorded",inplace=True)

# %%
care["Sleep_Hours"] = care["Sleep_Hours"].fillna(care["Sleep_Hours"].median())

# %%
care["BMI"] = care["BMI"].fillna(care["BMI"].median())

# %%
care.loc[care["Age"] > 100, "Age"] = None

care["Age"] = care["Age"].fillna(care["Age"].median())

# %%
care["City"] = care["City"].str.strip().str.title()

# %%
care[care.duplicated()]
# Out:
#      Patient_ID   Age  Gender        City  Occupation   BMI  \
# 2000     P00001  27.0  Female  Coimbatore    Business  26.0
# 2001     P00002  38.0  Female      Mumbai    Engineer  18.5
# 2002     P00003  23.0    Male       Delhi      Driver  34.1
# 2003     P00004  51.0  Female   Bengaluru    Business  32.6
# 2004     P00005  46.0    Male      Mumbai  Healthcare  29.0
# 2005     P00006  64.0  Female  Coimbatore     Student  32.9
# 2006     P00007  48.0  Female  Coimbatore     Student  20.9
# 2007     P00008  53.0    Male     Madurai       Sales  23.2
# 2008     P00009  33.0    Male     Chennai     Manager  25.8
# 2009     P00010  47.0    Male  Coimbatore     Student  30.3
# 2010     P00011  55.0  Female        Pune          IT  35.6
# 2011     P00012  69.0    Male   Hyderabad          IT  28.3
# 2012     P00013  34.0    Male     Madurai    Business  31.0
# 2013     P00014  23.0    Male   Bengaluru    Business  34.4
# 2014     P00015  64.0  Female     Chennai     Manager  28.4
# 2015     P00016  70.0    Male     Madurai    Engineer  24.8
# 2016     P00017  40.0  Female  Coimbatore       Sales  23.0
# 2017     P00018  55.0  Female        Pune  Healthcare  25.7
# 2018     P00019  54.0  Female   Bengaluru     Teacher  23.1
# 2019     P00020  64.0  Female     Madurai       Sales  33.8
#
#       Blood_Pressure_Systolic  Cholesterol  Blood_Sugar Smoking  ...  \
# 2000                      173          280          195      No  ...
# 2001                      147          233          188      No  ...
# 2002                      115          300          186      No  ...
# 2003                      163          251          212     Yes  ...
# 2004                      110          296          120     Yes  ...
# 2005                      175          218          199      No  ...
# 2006                      166          192          181      No  ...
# 2007                      168          246           90      No  ...
# 2008                      123          146          160     Yes  ...
# 2009                      113          269          150      No  ...
# 2010                      140          295          125      No  ...
# 2011                      143          190          213     Yes  ...
# 2012                      150          205          107     Yes  ...
# 2013                      151          232          129      No  ...
# 2014                      133          175           95     Yes  ...
# 2015                      149          188           72      No  ...
# 2016                      138          305          100      No  ...
# 2017                      122          190          188     Yes  ...
# 2018                      173          257          172      No  ...
# 2019                      160          263          156     Yes  ...
#
#      Daily_Steps  Sleep_Hours Stress_Level  Fast_Food_Meals_Per_Week  \
# 2000        4712          6.2            8                        10
# 2001       15440          6.5           10                         7
# 2002       11580          6.7            9                         7
# 2003       15867          7.4            9                         4
# 2004       13206          4.8            6                        10
# 2005       13820          6.5            2                         6
# 2006       14579          4.2            3                         0
# 2007       17805          9.0            7                         4
# 2008        5094          7.1            5                         8
# 2009        6788          5.3            2                         0
# 2010       17925          7.4            5                         6
# 2011        5375          4.2            9                         5
# 2012       10144          8.8            3                        10
# 2013       16493          6.7            8                        10
# 2014       14386          5.9            9                        10
# 2015        2467          4.9            9                         2
# 2016       13253          7.4            8                         9
# 2017       14925          8.2           10                         6
# 2018       12537          4.5            8                        10
# 2019       12202          6.5            4                         7
#
#       Water_Intake_Liters  Screen_Time_Hours  Family_History  \
# 2000                  2.1                5.4              No
# 2001                  2.4                6.8              No
# 2002                  3.8                5.4             Yes
# 2003                  2.6               11.6              No
# 2004                  3.0                9.5              No
# 2005                  4.1                1.6              No
# 2006                  3.3               11.2             Yes
# 2007                  2.6                4.6              No
# 2008                  3.6                9.0              No
# 2009                  2.4               10.9              No
# 2010                  2.0               10.0             Yes
# 2011                  3.1               11.7              No
# 2012                  3.1               10.2             Yes
# 2013                  3.0                3.1              No
# 2014                  3.3               11.6             Yes
# 2015                  1.6               10.8             Yes
# 2016                  2.2                1.8             Yes
# 2017                  1.7                5.9             Yes
# 2018                  4.0               11.5             Yes
# 2019                  2.8                7.9              No
#
#       Resting_Heart_Rate  Heart_Attack Hospital_Visits_Last_Year
# 2000                  77            No                         6
# 2001                  91            No                         7
# 2002                  73           Yes                         4
# 2003                 101            No                         7
# 2004                  99            No                         2
# 2005                  96            No                         5
# 2006                  83            No                        10
# 2007                  83            No                         1
# 2008                  91            No                         4
# 2009                  81            No                         0
# 2010                 102            No                         6
# 2011                  56           Yes                         6
# 2012                  96            No                         8
# 2013                  64            No                         7
# 2014                  60           Yes                         2
# 2015                  78           Yes                         1
# 2016                  86            No                         4
# 2017                  82           Yes                         4
# 2018                  82           Yes                         5
# 2019                  60           Yes                         8
#
# [20 rows x 23 columns]

# %%
care=care.drop_duplicates()

# %%
care.to_csv("Cleaned_data.csv",index=False)

# %%
care.isnull().sum()
# Out:
# Patient_ID                   0
# Age                          0
# Gender                       0
# City                         0
# Occupation                   0
# BMI                          0
# Blood_Pressure_Systolic      0
# Cholesterol                  0
# Blood_Sugar                  0
# Smoking                      0
# Alcohol_Consumption          0
# Exercise_Hours_Per_Week      0
# Gym_Member                   0
# Daily_Steps                  0
# Sleep_Hours                  0
# Stress_Level                 0
# Fast_Food_Meals_Per_Week     0
# Water_Intake_Liters          0
# Screen_Time_Hours            0
# Family_History               0
# Resting_Heart_Rate           0
# Heart_Attack                 0
# Hospital_Visits_Last_Year    0
# dtype: int64

# %%
print("Cleaned Cities:", care['City'].unique())
# Out:
# Cleaned Cities: <ArrowStringArray>
# ['Coimbatore',     'Mumbai',      'Delhi',  'Bengaluru',    'Madurai',
#     'Chennai',       'Pune',  'Hyderabad', 'Unrecorded']
# Length: 9, dtype: str

# %% [markdown]
# # sporting outlayers

# %%
plt.figure(figsize=(10, 4))
sns.boxplot(x=care['Age'], color='salmon')
plt.title("Box Plot for Age to Spot Outliers")
plt.xlabel("Age")
plt.show()

# %% [markdown]
# # Age Histogram

# %%
# Create a figure
fig, ax = plt.subplots(figsize=(8, 5))

# Plot the age distribution
sns.histplot(data=care, x="Age", bins=15, kde=True, ax=ax)

# Add title and labels
ax.set_title("Age Distribution")
ax.set_xlabel("Age")
ax.set_ylabel("Count")

plt.tight_layout()
plt.show()

plt.show()

# %% [markdown]
# # What is the demographic breakdown of our sample?
# # 1 Age Distribution Histogram
# # 2 Gender Split Pie Chart
# # 3 Sorted Occupation Count Plot

# %%
# Create three plots in one row
fig, axes = plt.subplots(1, 3, figsize=(20, 5))

# Age Distribution
sns.histplot(data=care, x="Age", bins=15, kde=True, ax=axes[0])
axes[0].set_title("Age Distribution")
axes[0].set_xlabel("Age")
axes[0].set_ylabel("Count")

# Gender Distribution
gender_counts = care["Gender"].value_counts()

axes[1].pie(
    gender_counts,
    labels=gender_counts.index,
    autopct="%1.1f%%",
    startangle=90
)
axes[1].set_title("Gender Distribution")

# Occupation Distribution
occupation_order = care["Occupation"].value_counts().index

sns.countplot(
    data=care,
    y="Occupation",
    order=occupation_order,
    ax=axes[2]
)

axes[2].set_title("Occupation Distribution")
axes[2].set_xlabel("Count")
axes[2].set_ylabel("Occupation")

plt.tight_layout()
plt.show()

# %% [markdown]
# # What do the primary health vital ranges look like?
# # 1. BMI Distribution with KDE
# # 2. Cholesterol Distribution with KDE
# # 3. Systolic Blood Pressure Distribution with KDE

# %%
# Create three plots in one row
fig, axes = plt.subplots(1, 3, figsize=(18, 5))

# BMI Distribution
sns.histplot(data=care, x="BMI", kde=True, ax=axes[0],color='teal')
axes[0].set_title("BMI Distribution")
axes[0].set_xlabel("BMI")
axes[0].set_ylabel("Count")

# Cholesterol Distribution
sns.histplot(data=care, x="Cholesterol", kde=True, ax=axes[1],color='coral')
axes[1].set_title("Cholesterol Distribution")
axes[1].set_xlabel("Cholesterol")
axes[1].set_ylabel("Count")

# Blood Pressure Distribution
sns.histplot(data=care, x="Blood_Pressure_Systolic", kde=True, ax=axes[2],color='crimson')
axes[2].set_title("Systolic Blood Pressure Distribution")
axes[2].set_xlabel("Systolic Blood Pressure")
axes[2].set_ylabel("Count")

plt.tight_layout()
plt.show()

# %% [markdown]
# # Plot 1: Box Plot (Clinical Metric vs. Discrete Target)

# %%
df_numeric_eval = care.copy()
df_numeric_eval['Heart_Attack_Flag'] = df_numeric_eval['Heart_Attack'].map({'Yes': 1, 'No': 0})

core_metrics = [
    'Age', 'BMI', 'Blood_Pressure_Systolic', 'Cholesterol', 'Blood_Sugar',
    'Exercise_Hours_Per_Week', 'Daily_Steps', 'Sleep_Hours', 'Stress_Level', 
    'Resting_Heart_Rate', 'Heart_Attack_Flag'
]

# %%
# Create two plots side by side
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# Box Plot: Blood Pressure vs Heart Attack
sns.boxplot(
    data=care,
    x="Heart_Attack",
    y="Blood_Pressure_Systolic",
    ax=axes[0]
)

axes[0].set_title("Blood Pressure vs Heart Attack")
axes[0].set_xlabel("Heart Attack")
axes[0].set_ylabel("Systolic Blood Pressure")

# Scatter Plot: Exercise Hours vs Daily Steps
sns.scatterplot(
    data=care,
    x="Exercise_Hours_Per_Week",
    y="Daily_Steps",
    hue="Heart_Attack",
    ax=axes[1]
)

axes[1].set_title("Exercise Hours vs Daily Steps")
axes[1].set_xlabel("Exercise Hours Per Week")
axes[1].set_ylabel("Daily Steps")
axes[1].legend(title="Heart Attack")

plt.tight_layout()
plt.show()

# %%
# Plot 3: Heatmap (System-Wide Correlations)
fig, axes = plt.subplots(1, 1, figsize=(18, 6))

corr_matrix = df_numeric_eval[core_metrics].corr()

sns.heatmap(
    corr_matrix,
    annot=True,
    cmap="coolwarm",
    fmt=".2f",
    linewidths=0.5,
    ax=axes
)

axes.set_title("System Correlation Matrix")
plt.xticks(rotation=45, ha="right")
plt.tight_layout()
plt.show()

# %%
# Create two plots side by side
fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Heart Attack by Smoking Status
sns.countplot(
    data=care,
    x="Smoking",
    hue="Heart_Attack",
    ax=axes[0]
)

axes[0].set_title("Heart Attack by Smoking Status")
axes[0].set_xlabel("Smoking")
axes[0].set_ylabel("Count")
axes[0].legend(title="Heart Attack")

# Heart Attack by Family History
sns.countplot(
    data=care,
    x="Family_History",
    hue="Heart_Attack",
    ax=axes[1]
)

axes[1].set_title("Heart Attack by Family History")
axes[1].set_xlabel("Family History")
axes[1].set_ylabel("Count")
axes[1].legend(title="Heart Attack")

plt.tight_layout()
plt.show()

# %%
# Load the dataset
care = pd.read_csv("Cleaned_data.csv")

# Remove duplicate patients
care = care.drop_duplicates(subset="Patient_ID")

# Standardize text values
care["Smoking"] = care["Smoking"].replace("Y", "Yes")
care["City"] = care["City"].str.strip().str.title()

# Fill missing values
care["BMI"] = care["BMI"].fillna(care["BMI"].median())
care["Sleep_Hours"] = care["Sleep_Hours"].fillna(care["Sleep_Hours"].median())
care["Hospital_Visits_Last_Year"] = care["Hospital_Visits_Last_Year"].fillna(
    care["Hospital_Visits_Last_Year"].median()
)

# Remove unrealistic ages
care = care[care["Age"] < 100]

# Display the cleaned dataset
print(care)
# Out:
#      Patient_ID   Age  Gender        City  Occupation   BMI  \
# 0        P00001  27.0  Female  Coimbatore    Business  26.0
# 1        P00002  38.0  Female      Mumbai    Engineer  18.5
# 2        P00003  23.0    Male       Delhi      Driver  34.1
# 3        P00004  51.0  Female   Bengaluru    Business  32.6
# 4        P00005  46.0    Male      Mumbai  Healthcare  29.0
# ...         ...   ...     ...         ...         ...   ...
# 1995     P01996  40.0    Male      Mumbai    Engineer  26.3
# 1996     P01997  34.0  Female     Madurai     Teacher  34.6
# 1997     P01998  22.0  Female  Coimbatore     Teacher  25.3
# 1998     P01999  54.0  Female     Chennai     Manager  32.7
# 1999     P02000  34.0  Female        Pune     Teacher  21.7
#
#       Blood_Pressure_Systolic  Cholesterol  Blood_Sugar Smoking  ...  \
# 0                         173          280          195      No  ...
# 1                         147          233          188      No  ...
# 2                         115          300          186      No  ...
# 3                         163          251          212     Yes  ...
# 4                         110          296          120     Yes  ...
# ...                       ...          ...          ...     ...  ...
# 1995                      125          204          176     Yes  ...
# 1996                      147          150           83      No  ...
# 1997                      105          243          139      No  ...
# 1998                      111          234          144      No  ...
# 1999                      121          236           89      No  ...
#
#      Daily_Steps  Sleep_Hours Stress_Level  Fast_Food_Meals_Per_Week  \
# 0           4712          6.2            8                        10
# 1          15440          6.5           10                         7
# 2          11580          6.7            9                         7
# 3          15867          7.4            9                         4
# 4          13206          4.8            6                        10
# ...          ...          ...          ...                       ...
# 1995       16650          7.6           10                         8
# 1996       16518          4.8            6                         9
# 1997        8312          5.6            7                         8
# 1998        9262          8.8            2                         8
# 1999       14472          6.6            6                         4
#
#       Water_Intake_Liters  Screen_Time_Hours  Family_History  \
# 0                     2.1                5.4              No
# 1                     2.4                6.8              No
# 2                     3.8                5.4             Yes
# 3                     2.6               11.6              No
# 4                     3.0                9.5              No
# ...                   ...                ...             ...
# 1995                  1.4                7.2              No
# 1996                  1.0                7.6              No
# 1997                  1.3               10.6             Yes
# 1998                  2.1               10.6              No
# 1999                  1.8                8.4             Yes
#
#       Resting_Heart_Rate  Heart_Attack Hospital_Visits_Last_Year
# 0                     77            No                         6
# 1                     91            No                         7
# 2                     73           Yes                         4
# 3                    101            No                         7
# 4                     99            No                         2
# ...                  ...           ...                       ...
# 1995                  99            No                         1
# 1996                 100            No                         3
# 1997                  92            No                         2
# 1998                 101            No                         1
# 1999                  80            No                        10
#
# [2000 rows x 23 columns]

# %%
# Load the dataset
care = pd.read_excel(
    r"C:\Users\user\Pictures\Desktop\Heart_Health_Lifestyle_Analytics\Dataset\Heart_Health_Lifestyle_Analytics_2000_Records.xlsx", 
    sheet_name="Heart_Health_Data"
)

# Clean the data
care = care.drop_duplicates(subset="Patient_ID")
care["Smoking"] = care["Smoking"].replace("Y", "Yes")
care["City"] = care["City"].str.strip().str.title()

# Fill missing values
care["BMI"] = care["BMI"].fillna(care["BMI"].median())
care["Sleep_Hours"] = care["Sleep_Hours"].fillna(care["Sleep_Hours"].median())
care["Hospital_Visits_Last_Year"] = care["Hospital_Visits_Last_Year"].fillna(
    care["Hospital_Visits_Last_Year"].median()
)

# Remove invalid ages
care = care[care["Age"] < 100]

# Create a numeric column for correlation
care["Heart_Attack_Flag"] = care["Heart_Attack"].map({"Yes": 1, "No": 0})

# Columns used for the correlation heatmap
columns = [
    "Age",
    "BMI",
    "Blood_Pressure_Systolic",
    "Cholesterol",
    "Blood_Sugar",
    "Exercise_Hours_Per_Week",
    "Daily_Steps",
    "Sleep_Hours",
    "Stress_Level",
    "Resting_Heart_Rate",
    "Heart_Attack_Flag"
]

# Create the dashboard
fig = plt.figure(figsize=(20, 10))
grid = plt.GridSpec(2, 3)

# Age Distribution
ax1 = fig.add_subplot(grid[0, 0])

sns.histplot(data=care, x="Age", bins=15, kde=True, ax=ax1)

ax1.set_title("Age Distribution")
ax1.set_xlabel("Age")
ax1.set_ylabel("Count")

# Blood Pressure Distribution
ax2 = fig.add_subplot(grid[0, 1])

sns.histplot(
    data=care,
    x="Blood_Pressure_Systolic",
    kde=True,
    ax=ax2
)

ax2.set_title("Blood Pressure Distribution")
ax2.set_xlabel("Systolic Blood Pressure")
ax2.set_ylabel("Count")

# Correlation Heatmap
ax3 = fig.add_subplot(grid[0, 2])

corr = care[columns].corr()

sns.heatmap(corr, cmap="coolwarm", ax=ax3)

ax3.set_title("Correlation Matrix")

# Exercise vs Daily Steps
ax4 = fig.add_subplot(grid[1, :2])

sns.scatterplot(
    data=care,
    x="Exercise_Hours_Per_Week",
    y="Daily_Steps",
    hue="Heart_Attack",
    ax=ax4
)

ax4.set_title("Exercise Hours vs Daily Steps")
ax4.set_xlabel("Exercise Hours Per Week")
ax4.set_ylabel("Daily Steps")

# Family History vs Smoking
ax5 = fig.add_subplot(grid[1, 2])

sns.countplot(
    data=care,
    x="Family_History",
    hue="Smoking",
    ax=ax5
)

ax5.set_title("Family History and Smoking")
ax5.set_xlabel("Family History")
ax5.set_ylabel("Count")

# Dashboard title
plt.suptitle("Heart Health Dashboard", fontsize=16)

plt.tight_layout()
plt.show()

# %%
# Set plot style
sns.set_style("whitegrid")

# Load the dataset
excel_path = r"C:\Users\user\Pictures\Desktop\Heart_Health_Lifestyle_Analytics\Dataset\Heart_Health_Lifestyle_Analytics_2000_Records.xlsx"
care = pd.read_excel(excel_path, sheet_name='Heart_Health_Data')

# -----------------------
# Data Cleaning
# -----------------------

# Remove duplicate records
care = care.drop_duplicates(subset="Patient_ID")

# Standardize values
care["Smoking"] = care["Smoking"].replace("Y", "Yes")
care["City"] = care["City"].str.strip().str.title()

# Fill missing values
care["BMI"] = care["BMI"].fillna(care["BMI"].median())
care["Sleep_Hours"] = care["Sleep_Hours"].fillna(care["Sleep_Hours"].median())
care["Hospital_Visits_Last_Year"] = care["Hospital_Visits_Last_Year"].fillna(
    care["Hospital_Visits_Last_Year"].median()
)

# Remove unrealistic ages
care = care[care["Age"] < 100]

# Convert Heart Attack to numeric for correlation
care["Heart_Attack_Flag"] = care["Heart_Attack"].map({"Yes": 1, "No": 0})

# Columns used for correlation
columns = [
    "Age",
    "BMI",
    "Blood_Pressure_Systolic",
    "Cholesterol",
    "Blood_Sugar",
    "Exercise_Hours_Per_Week",
    "Daily_Steps",
    "Sleep_Hours",
    "Stress_Level",
    "Resting_Heart_Rate",
    "Heart_Attack_Flag"
]

# -----------------------
# Dashboard
# -----------------------

fig = plt.figure(figsize=(20, 10))
grid = plt.GridSpec(2, 3)

# Age Distribution
ax1 = fig.add_subplot(grid[0, 0])

sns.histplot(data=care, x="Age", bins=15, kde=True, ax=ax1)

ax1.set_title("Age Distribution")
ax1.set_xlabel("Age")
ax1.set_ylabel("Count")

# Blood Pressure Distribution
ax2 = fig.add_subplot(grid[0, 1])

sns.histplot(data=care, x="Blood_Pressure_Systolic", kde=True, ax=ax2)

ax2.set_title("Blood Pressure Distribution")
ax2.set_xlabel("Systolic Blood Pressure")
ax2.set_ylabel("Count")

# Correlation Heatmap
ax3 = fig.add_subplot(grid[0, 2])

corr = care[columns].corr()

sns.heatmap(corr, cmap="coolwarm", ax=ax3)

ax3.set_title("Correlation Matrix")

# Exercise vs Daily Steps
ax4 = fig.add_subplot(grid[1, :2])

sns.scatterplot(
    data=care,
    x="Exercise_Hours_Per_Week",
    y="Daily_Steps",
    hue="Heart_Attack",
    ax=ax4
)

ax4.set_title("Exercise Hours vs Daily Steps")
ax4.set_xlabel("Exercise Hours Per Week")
ax4.set_ylabel("Daily Steps")

# Family History vs Smoking
ax5 = fig.add_subplot(grid[1, 2])

sns.countplot(
    data=care,
    x="Family_History",
    hue="Smoking",
    ax=ax5
)

ax5.set_title("Family History vs Smoking")
ax5.set_xlabel("Family History")
ax5.set_ylabel("Count")

# Dashboard title
plt.suptitle("Heart Health Dashboard", fontsize=16)

plt.tight_layout()
plt.show()
